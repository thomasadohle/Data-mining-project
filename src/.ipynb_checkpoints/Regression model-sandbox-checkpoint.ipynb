# %% [markdown]
# ### Global imports and loading the data

# %%
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.metrics import explained_variance_score, mean_squared_error
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, mean_squared_error
from sklearn.model_selection import train_test_split

white_wine_data = pd.read_csv('winequality-white.csv', sep=';')
red_wine_data = pd.read_csv('winequality-red.csv', sep=';')
all_data = pd.concat([white_wine_data, red_wine_data])

# %%
def generate_regression_data(wine_type='red', features=None):
    if wine_type == 'red':
        data = red_wine_data
    elif wine_type == 'both':
        data = all_data
    elif wine_type == 'white':
        data = white_wine_data
    else:
        raise Exception ('Invalid selection for wine_type')
    y = data['quality']
    # feature=None corresponds to calculating data for all features
    if features:
        X = data[features]
    else:
        X = data.drop(columns='quality')
    
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=.8, test_size=.2)
    reg = LinearRegression().fit(x_train,y_train)
    prediction = reg.predict(x_test)
    coefficients = reg.coef_
    mse = np.mean((prediction, y_test))
    variance = reg.score(x_test, y_test)
    data = dict(
        feature=X,
        regression=reg,
        prediction=prediction,
        coefficients=coefficients,
        mse=mse,
        variance=variance,
        x_test=x_test,
        x_train=x_train,
        y_test=y_test,
        y_train=y_train,
    )
    return data

def print_data(data):
    """
    Nicely formats data produced by generate_regression_data
    """
    print('Coefficients: \n {}'.format(data['coefficients']))
    print('Mean Squared Error: \n{}'.format(data['mse']))
    print('Variance score: \n{}'.format(data['variance']))
    
def plot_regression(data):
    """
    Plots data from regression model using a single feature
    """
    plt.scatter(data['x_test'], data['y_test'], color='green', label='Test Data')
    plt.scatter(data['x_train'], data['y_train'], color='orange', label='Training Data')
    plt.plot(data['x_test'], data['prediction'], color='blue')
    return plt

# %% [markdown]
# #### Generate regression model for each feature independently. First for red and white together, then red only, then white only

# %%
features = list(red_wine_data.columns)
features.remove('quality')

# %%
# Red and white wine
for feature in features:
    print('{} data for feature {}'.format('Red and white wine', feature))
    data = generate_regression_data(wine_type='both', features=[feature])
    print_data(data)
    plot = plot_regression(data)
    plot.show()
# Out:
# Red and white wine data for feature fixed acidity
# Coefficients:
#  [-0.04629216]
# Mean Squared Error:
# 5.830047908686068
# Variance score:
# 0.008086631393300792
# Red and white wine data for feature volatile acidity
# Coefficients:
#  [-1.39975411]
# Mean Squared Error:
# 5.809336850784608
# Variance score:
# 0.06664168136797877
# Red and white wine data for feature citric acid
# Coefficients:
#  [0.54607226]
# Mean Squared Error:
# 5.817788104866513
# Variance score:
# 0.004327900140117635
# Red and white wine data for feature residual sugar
# Coefficients:
#  [-0.00746062]
# Mean Squared Error:
# 5.8038214984221135
# Variance score:
# -0.002322717281273201
# Red and white wine data for feature chlorides
# Coefficients:
#  [-5.22500896]
# Mean Squared Error:
# 5.8208339715735535
# Variance score:
# 0.031550338869665406
# Red and white wine data for feature free sulfur dioxide
# Coefficients:
#  [0.00235461]
# Mean Squared Error:
# 5.813794174778636
# Variance score:
# 0.005335484007836788
# Red and white wine data for feature total sulfur dioxide
# Coefficients:
#  [-0.0007765]
# Mean Squared Error:
# 5.8183688744475495
# Variance score:
# -0.0018207397319487395
# Red and white wine data for feature density
# Coefficients:
#  [-86.85591171]
# Mean Squared Error:
# 5.814507901962188
# Variance score:
# 0.09807688813653515
# Red and white wine data for feature pH
# Coefficients:
#  [0.15619839]
# Mean Squared Error:
# 5.827606514558942
# Variance score:
# -0.003062004231016102
# Red and white wine data for feature sulphates
# Coefficients:
#  [0.24096609]
# Mean Squared Error:
# 5.810473042430084
# Variance score:
# -0.0002096875244073093
# Red and white wine data for feature alcohol
# Coefficients:
#  [0.32446235]
# Mean Squared Error:
# 5.824638899493773
# Variance score:
# 0.20465707809691536

# %%
# Red wine only 
for feature in features:
    print('data for feature {}'.format(feature))
    data = generate_regression_data(wine_type='red', features=[feature])
    print_data(data)
    plot = plot_data(data)
    plot.show()
# Out:
# data for feature fixed acidity
# Coefficients:
#  [0.06376971]
# Mean Squared Error:
# 5.657091202988172
# Variance score:
# -0.003620984785642767
# data for feature volatile acidity
# Coefficients:
#  [-1.78658661]
# Mean Squared Error:
# 5.646835282897612
# Variance score:
# 0.15117896991212287
# data for feature citric acid
# Coefficients:
#  [0.95058991]
# Mean Squared Error:
# 5.638063026243048
# Variance score:
# 0.05070519955705777
# data for feature residual sugar
# Coefficients:
#  [0.00702334]
# Mean Squared Error:
# 5.643631668000923
# Variance score:
# -0.0006367947989718292
# data for feature chlorides
# Coefficients:
#  [-2.40806009]
# Mean Squared Error:
# 5.650739850044112
# Variance score:
# 0.0021241175875977847
# data for feature free sulfur dioxide
# Coefficients:
#  [-0.00378768]
# Mean Squared Error:
# 5.623132884666382
# Variance score:
# 0.0011613438657112063
# data for feature total sulfur dioxide
# Coefficients:
#  [-0.00472671]
# Mean Squared Error:
# 5.621954029812658
# Variance score:
# 0.020728411941190905
# data for feature density
# Coefficients:
#  [-81.56765259]
# Mean Squared Error:
# 5.6235534857445115
# Variance score:
# 0.0034650907428269706
# data for feature pH
# Coefficients:
#  [-0.2616584]
# Mean Squared Error:
# 5.609660142084406
# Variance score:
# -0.005235000278230206
# data for feature sulphates
# Coefficients:
#  [1.16608893]
# Mean Squared Error:
# 5.638859699565696
# Variance score:
# 0.06821737764373426
# data for feature alcohol
# Coefficients:
#  [0.35665387]
# Mean Squared Error:
# 5.640714961859318
# Variance score:
# 0.24178860572147143

# %%
# White wine only
for feature in features:
    print('data for feature {}'.format(feature))
    data = generate_regression_data(wine_type='white', features=[feature])
    print_data(data)
    #plot = plot_data(data)
    #plot.show()
# Out:
# data for feature fixed acidity
# Coefficients:
#  [-0.12677114]
# Mean Squared Error:
# 5.888153143339063
# Variance score:
# 0.005264475707976057
# data for feature volatile acidity
# Coefficients:
#  [-1.8050962]
# Mean Squared Error:
# 5.878569995000867
# Variance score:
# 0.01772677717377069
# data for feature citric acid
# Coefficients:
#  [0.01309456]
# Mean Squared Error:
# 5.8735710617519
# Variance score:
# -0.0004750405746249964
# data for feature residual sugar
# Coefficients:
#  [-0.01586008]
# Mean Squared Error:
# 5.8781734931495535
# Variance score:
# 0.013471926376675825
# data for feature chlorides
# Coefficients:
#  [-8.06688211]
# Mean Squared Error:
# 5.874788348096514
# Variance score:
# 0.04914947080629084
# data for feature free sulfur dioxide
# Coefficients:
#  [0.00064142]
# Mean Squared Error:
# 5.890948916507067
# Variance score:
# -0.002679770442610696
# data for feature total sulfur dioxide
# Coefficients:
#  [-0.00359278]
# Mean Squared Error:
# 5.864288548826939
# Variance score:
# 0.031617584510492236
# data for feature density
# Coefficients:
#  [-91.05599826]
# Mean Squared Error:
# 5.871662573976065
# Variance score:
# 0.0908991814347272
# data for feature pH
# Coefficients:
#  [0.59987193]
# Mean Squared Error:
# 5.869793605838227
# Variance score:
# 0.0077712343561122665
# data for feature sulphates
# Coefficients:
#  [0.38567191]
# Mean Squared Error:
# 5.8755275295467015
# Variance score:
# 0.004381377178033996
# data for feature alcohol
# Coefficients:
#  [0.3081693]
# Mean Squared Error:
# 5.8824622858516955
# Variance score:
# 0.21882843675969677

# %% [markdown]
# #### Check if our regression models against correlation values

# %%
# Red and white wine
all_data.corr()['quality'].drop('quality').sort_values(ascending=False)
# Out:
# alcohol                 0.444319
# citric acid             0.085532
# free sulfur dioxide     0.055463
# sulphates               0.038485
# pH                      0.019506
# residual sugar         -0.036980
# total sulfur dioxide   -0.041385
# fixed acidity          -0.076743
# chlorides              -0.200666
# volatile acidity       -0.265699
# density                -0.305858
# Name: quality, dtype: float64

# %% [markdown]
# The 3 strongest correlations (alcohol, density, and volatile acidity) match the 3 regression models with the highest variance, which is what we expect.

# %%
# Red wine only
red_wine_data.corr()['quality'].drop('quality').sort_values(ascending=False)
# Out:
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# The 3 strongest correlations (alcohol, volatile acidity, and sulphate) match the 3 regression models with the highest variance, which is what we expect.

# %%
# White wine only
white_wine_data.corr()['quality'].drop('quality').sort_values(ascending=False)
# Out:
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64

# %% [markdown]
# The 3 strongest correlations (alcohol, density, and chlorides) match the 3 regression models with the highest variance, which is what we expect.

# %%
data = generate_regression_data(wine_type='red', features=['alcohol', 'sulphates', 'citric acid', 'volatile acidity'])
print_data(data)
# Out:
# Coefficients:
#  [ 0.30234709  0.569356   -0.06848093 -1.36141063]
# Mean Squared Error:
# 5.572769361008394
# Variance score:
# 0.34457541469279296

# %%
data = generate_regression_data(wine_type='white', features=['alcohol', 'density'])
print_data(data)
# Out:
# Coefficients:
#  [ 0.36386196 28.3152997 ]
# Mean Squared Error:
# 5.896202026563261
# Variance score:
# 0.20317049972873802

# %%
data = generate_regression_data(wine_type='white')
print_data(data)
# Out:
# Coefficients:
#  [ 3.97474391e-02 -1.95381712e+00  1.13204085e-01  7.86165898e-02
#  -2.04995050e-01  3.29416464e-03 -4.36402710e-04 -1.35381763e+02
#   6.56242634e-01  6.42437252e-01  2.06657044e-01]
# Mean Squared Error:
# 5.846903333012943
# Variance score:
# 0.2924675712655812

# %%
data = generate_regression_data(wine_type='both')
print_data(data)
# Out:
# Coefficients:
#  [ 6.40805475e-02 -1.94875318e+00 -2.76374904e-03  7.58723048e-02
#  -1.56904365e-01  4.98158497e-03 -5.48712773e-04 -1.37838379e+02
#   6.90569810e-01  5.96147103e-01  2.07698726e-01]
# Mean Squared Error:
# 5.859263276080508
# Variance score:
# 0.23373771486543793
