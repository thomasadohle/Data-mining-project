# %% [markdown]
# ### Regression analysis

# %%
# Global imports and loading the data
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import explained_variance_score, mean_squared_error
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, mean_squared_error
from sklearn.model_selection import train_test_split

white_wine_data = pd.read_csv('winequality-white.csv', sep=';')
red_wine_data = pd.read_csv('winequality-red.csv', sep=';')
all_data = pd.concat([white_wine_data, red_wine_data])

# %%
def generate_regression_data(wine_type='red', features=None):
    if wine_type == 'red':
        data = red_wine_data
    elif wine_type == 'both':
        data = all_data
    elif wine_type == 'white':
        data = white_wine_data
    else:
        raise Exception ('Invalid selection for wine_type')
    y = data['quality']
    # feature=None corresponds to calculating data for all features
    if features:
        X = data[features]
    else:
        X = data.drop(columns='quality')
    
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=.8, test_size=.2)
    reg = LinearRegression().fit(x_train,y_train)
    prediction = reg.predict(x_test)
    coefficients = reg.coef_
    mse = np.mean((prediction, y_test))
    variance = reg.score(x_test, y_test)
    data = dict(
        feature=X,
        regression=reg,
        prediction=prediction,
        coefficients=coefficients,
        mse=mse,
        variance=variance,
        x_test=x_test,
        x_train=x_train,
        y_test=y_test,
        y_train=y_train,
    )
    return data

def print_data(data):
    """
    Nicely formats data produced by generate_regression_data
    """
    print('Coefficients: \n {}'.format(data['coefficients']))
    print('Mean Squared Error: \n{}'.format(data['mse']))
    print('Variance score: \n{}'.format(data['variance']))
    
def plot_regression(data):
    """
    Plots data from regression model using a single feature
    """
    plt.scatter(data['x_test'], data['y_test'], color='green', label='Test Data')
    plt.scatter(data['x_train'], data['y_train'], color='orange', label='Training Data')
    plt.plot(data['x_test'], data['prediction'], color='blue')
    return plt

# %% [markdown]
# #### Generate regression model for each feature independently. First for red and white together, then red only, then white only

# %%
features = list(red_wine_data.columns)
features.remove('quality')

# %%
# Red and white wine
for feature in features:
    print('{} data for feature {}'.format('Red and white wine', feature))
    data = generate_regression_data(wine_type='both', features=[feature])
    print_data(data)
    plot = plot_regression(data)
    plot.show()
# Out:
# Red and white wine data for feature fixed acidity
# Coefficients:
#  [-0.04300787]
# Mean Squared Error:
# 5.816965851895543
# Variance score:
# 0.011788662249674231
# Red and white wine data for feature volatile acidity
# Coefficients:
#  [-1.45806128]
# Mean Squared Error:
# 5.835154417857495
# Variance score:
# 0.04769808569201295
# Red and white wine data for feature citric acid
# Coefficients:
#  [0.55347229]
# Mean Squared Error:
# 5.839156569096805
# Variance score:
# -0.0035745099028163807
# Red and white wine data for feature residual sugar
# Coefficients:
#  [-0.00751239]
# Mean Squared Error:
# 5.815195808039862
# Variance score:
# 3.2678247416373374e-05
# Red and white wine data for feature chlorides
# Coefficients:
#  [-4.88036986]
# Mean Squared Error:
# 5.81463531418664
# Variance score:
# 0.045634831259885544
# Red and white wine data for feature free sulfur dioxide
# Coefficients:
#  [0.00245886]
# Mean Squared Error:
# 5.8085538507645005
# Variance score:
# 0.003620338578211979
# Red and white wine data for feature total sulfur dioxide
# Coefficients:
#  [-0.00060009]
# Mean Squared Error:
# 5.810353124343276
# Variance score:
# 0.0019476419614242735
# Red and white wine data for feature density
# Coefficients:
#  [-88.63927025]
# Mean Squared Error:
# 5.831657873949297
# Variance score:
# 0.10039734513611154
# Red and white wine data for feature pH
# Coefficients:
#  [0.08757893]
# Mean Squared Error:
# 5.815784805850337
# Variance score:
# 0.0007038705922303157
# Red and white wine data for feature sulphates
# Coefficients:
#  [0.28106242]
# Mean Squared Error:
# 5.817312444221811
# Variance score:
# -0.0025259453486055072
# Red and white wine data for feature alcohol
# Coefficients:
#  [0.32436351]
# Mean Squared Error:
# 5.81514305295557
# Variance score:
# 0.20226332701155147

# %%
# Red wine only 
for feature in features:
    print('data for feature {}'.format(feature))
    data = generate_regression_data(wine_type='red', features=[feature])
    print_data(data)
    plot = plot_regression(data)
    plot.show()
# Out:
# data for feature fixed acidity
# Coefficients:
#  [0.05765668]
# Mean Squared Error:
# 5.630404559607675
# Variance score:
# 0.015960877211521174
# data for feature volatile acidity
# Coefficients:
#  [-1.88121156]
# Mean Squared Error:
# 5.617588758607978
# Variance score:
# 0.07677520240253777
# data for feature citric acid
# Coefficients:
#  [0.99632841]
# Mean Squared Error:
# 5.628261631997393
# Variance score:
# 0.02314133328470025
# data for feature residual sugar
# Coefficients:
#  [0.01874017]
# Mean Squared Error:
# 5.665903454333963
# Variance score:
# -0.019552519893687004
# data for feature chlorides
# Coefficients:
#  [-2.15005926]
# Mean Squared Error:
# 5.642134019145912
# Variance score:
# 0.010738303665964177
# data for feature free sulfur dioxide
# Coefficients:
#  [-0.00466297]
# Mean Squared Error:
# 5.600701498685598
# Variance score:
# -0.021615326097455423
# data for feature total sulfur dioxide
# Coefficients:
#  [-0.00506095]
# Mean Squared Error:
# 5.652253624390438
# Variance score:
# -0.0014808278143345621
# data for feature density
# Coefficients:
#  [-76.6225988]
# Mean Squared Error:
# 5.632916427562256
# Variance score:
# 0.023600932735893143
# data for feature pH
# Coefficients:
#  [-0.23885977]
# Mean Squared Error:
# 5.644019352291077
# Variance score:
# 0.005771025510287409
# data for feature sulphates
# Coefficients:
#  [1.27928877]
# Mean Squared Error:
# 5.629908715152584
# Variance score:
# 0.019370926725452042
# data for feature alcohol
# Coefficients:
#  [0.35217242]
# Mean Squared Error:
# 5.626087386785215
# Variance score:
# 0.2544348912664366

# %%
# White wine only
for feature in features:
    print('data for feature {}'.format(feature))
    data = generate_regression_data(wine_type='white', features=[feature])
    print_data(data)
    plot = plot_regression(data)
    plot.show()
# Out:
# data for feature fixed acidity
# Coefficients:
#  [-0.13204271]
# Mean Squared Error:
# 5.873152018832823
# Variance score:
# 0.001382710175220736
# data for feature volatile acidity
# Coefficients:
#  [-1.68583546]
# Mean Squared Error:
# 5.872337928845916
# Variance score:
# 0.04081001541388307
# data for feature citric acid
# Coefficients:
#  [-0.15568002]
# Mean Squared Error:
# 5.876056449175151
# Variance score:
# -0.0023231915742618625
# data for feature residual sugar
# Coefficients:
#  [-0.01706582]
# Mean Squared Error:
# 5.868314037417557
# Variance score:
# 0.010048992830493542
# data for feature chlorides
# Coefficients:
#  [-8.68106188]
# Mean Squared Error:
# 5.868148732667062
# Variance score:
# 0.038374595230830755
# data for feature free sulfur dioxide
# Coefficients:
#  [0.00010985]
# Mean Squared Error:
# 5.878934749987171
# Variance score:
# 0.00011498272242260743
# data for feature total sulfur dioxide
# Coefficients:
#  [-0.00355083]
# Mean Squared Error:
# 5.885580963401915
# Variance score:
# 0.03662533397621748
# data for feature density
# Coefficients:
#  [-91.50693842]
# Mean Squared Error:
# 5.884735248031333
# Variance score:
# 0.08890830917517567
# data for feature pH
# Coefficients:
#  [0.51486089]
# Mean Squared Error:
# 5.88531796140285
# Variance score:
# 0.01738965130151582
# data for feature sulphates
# Coefficients:
#  [0.37465723]
# Mean Squared Error:
# 5.8648415941164185
# Variance score:
# 0.002877570066202484
# data for feature alcohol
# Coefficients:
#  [0.31594273]
# Mean Squared Error:
# 5.859133673151547
# Variance score:
# 0.16791655488906743

# %% [markdown]
# #### Check our regression models against correlation values

# %%
# Red and white wine
print(all_data.corr()['quality'].drop('quality').sort_values(ascending=False))
sns.heatmap(all_data.corr())
# Out:
# alcohol                 0.444319
# citric acid             0.085532
# free sulfur dioxide     0.055463
# sulphates               0.038485
# pH                      0.019506
# residual sugar         -0.036980
# total sulfur dioxide   -0.041385
# fixed acidity          -0.076743
# chlorides              -0.200666
# volatile acidity       -0.265699
# density                -0.305858
# Name: quality, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# The 3 strongest correlations (alcohol, density, and volatile acidity) match the 3 regression models with the highest variance, which is what we expect.

# %%
# Red wine only
print(red_wine_data.corr()['quality'].drop('quality').sort_values(ascending=False))
sns.heatmap(red_wine_data.corr())
# Out:
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# The 3 strongest correlations (alcohol, volatile acidity, and sulphate) match the 3 regression models with the highest variance, which is what we expect.

# %%
# White wine only
print(white_wine_data.corr()['quality'].drop('quality').sort_values(ascending=False))
sns.heatmap(white_wine_data.corr())
# Out:
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# The 3 strongest correlations (alcohol, density, and chlorides) match the 3 regression models with the highest variance, which is what we expect.

# %% [markdown]
# #### Next, we generate regression models using all features. First for Red and white wine, then red only, then white only.

# %%
# Red and white
data = generate_regression_data(wine_type='both')
print_data(data)
# Out:
# Coefficients:
#  [ 5.13766164e-02 -1.34666299e+00 -1.24488449e-01  4.03718380e-02
#  -5.75594295e-01  5.55471166e-03 -2.42240137e-03 -4.56964312e+01
#   4.16887199e-01  7.38621967e-01  2.75626889e-01]
# Mean Squared Error:
# 5.811602876454725
# Variance score:
# 0.2915157470255263

# %% [markdown]
# The single feature regression model using alcohol had the highest variance, at ~.20. In this case, using all features produces a higher variance than any one feature independently

# %%
# Red only
data = generate_regression_data(wine_type='red')
print_data(data)
# Out:
# Coefficients:
#  [ 2.70174836e-02 -1.13060463e+00 -2.03951579e-01  1.85028278e-02
#  -1.70926892e+00  4.64507808e-03 -3.57149789e-03 -2.02439902e+01
#  -4.45876121e-01  8.59266070e-01  2.72133575e-01]
# Mean Squared Error:
# 5.61234763526219
# Variance score:
# 0.3350258655099002

# %% [markdown]
# The single feature regression model using alcohol had the highest variance, at ~.25. In this case, using all features produces a higher variance than any one feature independently

# %%
# White only
data = generate_regression_data(wine_type='white')
print_data(data)
# Out:
# Coefficients:
#  [ 4.13036900e-02 -1.93424925e+00 -2.06376429e-03  7.56424610e-02
#  -2.78736504e-01  3.57883046e-03 -1.56609616e-04 -1.36596752e+02
#   5.29282241e-01  5.79842370e-01  2.04801591e-01]
# Mean Squared Error:
# 5.90714088441927
# Variance score:
# 0.3044105108605608

# %% [markdown]
# The single feature regression model using alcohol had the highest variance, at ~.22. In this case, using all features produces a higher variance than any one feature independently

# %% [markdown]
# #### Next, we will attempt to use a combination of features to create a regression models whose variances are higher than the regression models which use all features. First for red and white wine, then red only, then white only. This could be computationally expensive. To decrease the amount of work, we will only consider features where abs(correlation) >= .1.

# %%
import itertools
def find_highest_variance_regression(wine_type, features):
    """
    Given a list of strings representing the column names of features, genereate regression models for 
    all possible combinations of features.
    """
    combos = []
    data_dict = {}
    for l in range(0, len(features)+1):
        for subset in itertools.combinations(both_features, l):
            combos.append(subset)
    for combo in combos:
        data = generate_regression_data(wine_type=wine_type, features=list(combo))
        data_dict[combo] = data
    max_key = max(data_dict, key=lambda tup: data_dict[tup]['variance'])
    return data_dict[max_key]

# %%
# Features of red wine + white wine dataset with correlations >=.1
both_features = ['alcohol', 'density', 'volatile acidity', 'chlorides']
both_data = find_highest_variance_regression('both', both_features)
print_data(both_data)
# Out:
# Coefficients:
#  [ 8.21726228e-02 -1.24030618e+00 -8.57539674e-02  4.81029252e-02
#  -4.85251416e-01  5.84869065e-03 -2.49047795e-03 -6.72860581e+01
#   4.36277414e-01  8.05288116e-01  2.56949810e-01]
# Mean Squared Error:
# 5.795792550716644
# Variance score:
# 0.2857334330988134

# %%
# Features of red wine with correlations >=.1
red_features = ['alcohol', 'sulphates', 'citric acid', 'fixed acidity', 'chlorides', 'density', 'total sulfur dioxide', 'volatile acidity']
red_data = find_highest_variance_regression('red', red_features)
print_data(red_data)
# Out:
# Coefficients:
#  [ 2.31818046e-02 -1.04067017e+00 -1.76593524e-01  1.43849192e-02
#  -1.88509461e+00  4.00488616e-03 -3.16239024e-03 -1.46487611e+01
#  -4.14654298e-01  9.44797651e-01  2.79717848e-01]
# Mean Squared Error:
# 5.635948307006703
# Variance score:
# 0.35582658426348823

# %%
# Features of white wine dataset with correlations >=.1
white_features = ['alcohol', 'density', 'chlorides', 'volatile acidity', 'total sulfur dioxide', 'fixed acidity']
white_data = find_highest_variance_regression('white', white_features)
print_data(white_data)
# Out:
# Coefficients:
#  [ 5.36222950e-02 -1.78012947e+00  5.69550584e-02  7.77231027e-02
#  -5.29470749e-01  3.89019908e-03 -3.06829085e-04 -1.45713544e+02
#   5.81142493e-01  7.36569439e-01  1.92547926e-01]
# Mean Squared Error:
# 5.893380379572537
# Variance score:
# 0.28691696206944106
